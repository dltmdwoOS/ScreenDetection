# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import ScreenDetection

# %%
s = ScreenDetection.screen_detection()

# %%
objects = s.detect("abcde.webp", threshold=0.85)

# %%
objects
# Out:
# [('person', 0.989, [546.74, 291.12, 607.14, 438.82]),
#  ('person', 0.997, [560.11, 333.25, 663.94, 523.94]),
#  ('person', 0.998, [978.27, 484.03, 1074.96, 799.85]),
#  ('person', 0.995, [264.7, 286.44, 342.83, 464.53]),
#  ('backpack', 0.957, [905.64, 413.31, 948.03, 473.88]),
#  ('person', 0.996, [1105.86, 460.49, 1199.87, 768.53]),
#  ('person', 0.991, [857.83, 378.82, 955.85, 608.67]),
#  ('person', 0.981, [371.16, 313.58, 430.43, 401.57]),
#  ('person', 0.929, [669.02, 234.24, 747.04, 473.1]),
#  ('person', 0.995, [398.5, 490.3, 496.15, 610.65]),
#  ('person', 0.862, [696.63, 428.93, 749.7, 495.36]),
#  ('person', 0.991, [855.75, 305.62, 926.59, 441.85]),
#  ('person', 0.979, [424.26, 324.86, 492.69, 471.39]),
#  ('person', 0.935, [700.8, 362.08, 769.82, 486.1]),
#  ('person', 0.989, [193.75, 512.92, 301.04, 753.17]),
#  ('backpack', 0.877, [1112.57, 495.01, 1175.57, 562.38]),
#  ('person', 0.959, [523.1, 374.93, 574.02, 448.8]),
# ...

# %%
import utils
utils.draw_rectangles("abcde.webp", objects)
# Out:
# Drawing box for person: (546.74, 291.12, 607.14, 438.82)
# Drawing box for person: (560.11, 333.25, 663.94, 523.94)
# Drawing box for person: (978.27, 484.03, 1074.96, 799.85)
# Drawing box for person: (264.7, 286.44, 342.83, 464.53)
# Drawing box for backpack: (905.64, 413.31, 948.03, 473.88)
# Drawing box for person: (1105.86, 460.49, 1199.87, 768.53)
# Drawing box for person: (857.83, 378.82, 955.85, 608.67)
# Drawing box for person: (371.16, 313.58, 430.43, 401.57)
# Drawing box for person: (669.02, 234.24, 747.04, 473.1)
# Drawing box for person: (398.5, 490.3, 496.15, 610.65)
# Drawing box for person: (696.63, 428.93, 749.7, 495.36)
# Drawing box for person: (855.75, 305.62, 926.59, 441.85)
# Drawing box for person: (424.26, 324.86, 492.69, 471.39)
# Drawing box for person: (700.8, 362.08, 769.82, 486.1)
# Drawing box for person: (193.75, 512.92, 301.04, 753.17)
# Drawing box for backpack: (1112.57, 495.01, 1175.57, 562.38)
# ...
